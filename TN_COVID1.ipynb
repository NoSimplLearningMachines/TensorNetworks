# %%
#!/usr/bin/env python3
import os
import random
import time
import torch
from torchmps import MPS
from torchvision import transforms, datasets
import argparse
import torchvision
from PIL import Image
import numpy as np

# %%
class_names = ['normal', 'covid','viral']
root_dir = '/home/mashjunior/loTeNet_pytorch/Covid-19_images/COVID-19_Radiography/COVID-19 Radiography Database/'
source_dirs = ['normal' ,'covid','viral']

# %%
parser = argparse.ArgumentParser()

# %%
parser.add_argument('--num_epochs', type=int, default=100, help='Number of training epochs')
parser.add_argument('--batch_size', type=int, default=64, help='Batch size')
parser.add_argument('--lr', type=float, default=5e-4, help='Learning rate')
parser.add_argument('--l2_reg', type=float, default=0, help='L2 regularisation')
parser.add_argument('--aug', action='store_true', default=False, help='Use data augmentation')
parser.add_argument('--data_path', type=str, default=root_dir,help='Path to data.')
parser.add_argument('--bond_dim', type=int, default=5, help='MPS Bond dimension')
parser.add_argument('--nChannel', type=int, default=1, help='Number of input channels')
parser.add_argument('--dense_net', action='store_true', default=False, help='Using Dense Net model')
# Out:
# _StoreTrueAction(option_strings=['--dense_net'], dest='dense_net', nargs=0, const=True, default=False, type=None, choices=None, help='Using Dense Net model', metavar=None)

# %%
args = parser.parse_args([])

# %%
# Miscellaneous initialization
torch.manual_seed(0)
start_time = time.time()

# MPS parameters
#bond_dim = 20
adaptive_mode = False
periodic_bc = False

# Training parameters
#num_train = 2000
#num_test = 1000
#batch_size = 100
num_epochs = args.num_epochs
learn_rate = args.lr
l2_reg = args.l2_reg


batch_size = args.batch_size
bond_dim = args.bond_dim


# LoTeNet parameters
adaptive_mode = False 
periodic_bc   = False

kernel = 2 # Stride along spatial dimensions
output_dim = 1 # output dimension
 
feature_dim = 2

#logFile = time.strftime("%Y%m%d_%H_%M")+'.txt'
#makeLogFile(logFile)

normTensor = 0.5*torch.ones(args.nChannel)
### Data processing and loading....

# %%
class ChestXRayDataset(torch.utils.data.Dataset):
    def __init__(self, image_dirs,transform):
        def get_images(class_name):
            images = [x for x in os.listdir(image_dirs[class_name]) if x.lower().endswith('png')]
            print(f'Found {len(images)}{class_name}')
            return images
        self.images={}
        self.class_names=['normal','covid', 'viral']
        for c in self.class_names:
            self.images[c]=get_images(c)
        self.image_dirs=image_dirs
        self.transform=transform
    def __len__(self):
        return sum([len(self.images[c]) for c in self.class_names])
    def __getitem__(self, index):
        class_name=random.choice(self.class_names)
        index=index%len(self.images[class_name])
        image_name=self.images[class_name][index]
        image_path =os.path.join(self.image_dirs[class_name], image_name)
        image=Image.open(image_path).convert('L')
        return self.transform(image), self.class_names.index(class_name)

# %%
### Data processing and loading....
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.Resize(size=(128,128)),
                                      transforms.RandomVerticalFlip(),
                                      transforms.RandomRotation(20),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=normTensor,std=normTensor)])

valid_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(size=(128,128)),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomRotation(20),
    torchvision.transforms.ToTensor(),
    transforms.Normalize(mean=normTensor,std=normTensor)
    #torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229,0.224,0.225])
])

# %%
train_dirs = {
    'normal': root_dir + 'train/normal',
    'covid': root_dir + 'train/covid',
    'viral': root_dir + 'train/viral'
}
train_dataset=ChestXRayDataset(train_dirs, train_transform)
# Out:
# Found 600normal
# Found 600covid
# Found 600viral

# %%
valid_dirs = {
    'normal': root_dir + '/valid/normal',
    'covid': root_dir + '/valid/covid',
    'viral': root_dir + '/valid/viral'
}

valid_dataset = ChestXRayDataset(valid_dirs, valid_transform)
# Out:
# Found 400normal
# Found 400covid
# Found 400viral

# %%
test_dirs = {
    'normal': root_dir + '/test/normal',
    'covid': root_dir + '/test/covid',
    'viral': root_dir + '/test/viral'
}

test_dataset = ChestXRayDataset(test_dirs, valid_transform)
# Out:
# Found 100normal
# Found 100covid
# Found 100viral

# %%
# Training parameters
num_train = 600
num_valid = 400
num_test = 100

# %%
mps = MPS(
    input_dim=128 ** 2,
    output_dim=3,
    bond_dim=bond_dim,
    adaptive_mode=adaptive_mode,
    periodic_bc=periodic_bc,
)

# %%
# Set our loss function and optimizer
loss_fun = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mps.parameters(), lr=learn_rate, weight_decay=l2_reg)

# %%
# Put MNIST data into dataloaders
samplers = {
    "train": torch.utils.data.SubsetRandomSampler(range(num_train)),
    "valid": torch.utils.data.SubsetRandomSampler(range(num_valid)),
    "test": torch.utils.data.SubsetRandomSampler(range(num_test)),
}
loaders = {
    name: torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, sampler=samplers[name], drop_last=True
    )
    for (name, dataset) in [("train", train_dataset), ("valid", valid_dataset), ("test", test_dataset)]
}
num_batches = {
    name: total_num // batch_size
    for (name, total_num) in [("train", num_train), ("valid", num_valid), ("test", num_test)]
}

# %%
samplers.items
# Out:
# <function dict.items>

# %%
num_batches
# Out:
# {'train': 9, 'valid': 6, 'test': 1}

# %%
#loaders['train'][0][0]

# %%
print(f"Maximum MPS bond dimension = {bond_dim}")
print(f" * {'Adaptive' if adaptive_mode else 'Fixed'} bond dimensions")
print(f" * {'Periodic' if periodic_bc else 'Open'} boundary conditions")
print(f"Using Adam w/ learning rate = {learn_rate:.1e}")
if l2_reg > 0:
    print(f" * L2 regularization = {l2_reg:.2e}")
print()
# Out:
# Maximum MPS bond dimension = 5
#  * Fixed bond dimensions
#  * Open boundary conditions
# Using Adam w/ learning rate = 5.0e-04

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def evaluate(loader):
     ### Evaluation funcntion for validation/testing

    with torch.no_grad():
        vl_acc = 0.
        vl_loss = 0.
        labelsNp = np.zeros(1)
        predsNp = np.zeros(1)
        model.eval()

        for i, (inputs, labels) in enumerate(loader):

            inputs = inputs.to(device).type(dtype=torch.float)
            labels = labels.to(device).type(dtype=torch.float)
            labelsNp = np.concatenate((labelsNp, labels.cpu().numpy()))

            # Inference
            scores = torch.sigmoid(model(inputs)).type(dtype=torch.float)

            preds = scores
            loss = loss_fun(scores, labels)
            predsNp = np.concatenate((predsNp, preds.cpu().numpy()))
            vl_loss += loss.item()

        # Compute AUC over the full (valid/test) set
        vl_acc = computeAuc(labelsNp[1:],predsNp[1:])
        vl_loss = vl_loss/len(loader)

    return vl_acc, vl_loss

# %%
maxAuc = 0
minLoss = 1e3
convCheck = 5
convIter = 0

# %%
# Let's start training!
for epoch_num in range(1, num_epochs + 1):
    running_loss = 0.0
    running_acc = 0.0

    for inputs, labels in loaders["train"]:
        inputs, labels = inputs.view([batch_size, 128 ** 2]), labels.data

        # Call our MPS to get logit scores and predictions
        scores = mps(inputs)
        _, preds = torch.max(scores, 1)

        # Compute the loss and accuracy, add them to the running totals
        loss = loss_fun(scores, labels)
        with torch.no_grad():
            accuracy = torch.sum(preds == labels).item() / batch_size
            running_loss += loss
            running_acc += accuracy

        # Backpropagate and update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"### Epoch {epoch_num} ###")
    print(f"Average loss:           {running_loss / num_batches['train']:.4f}")
    print(f"Average train accuracy: {running_acc / num_batches['train']:.4f}")

    # Evaluate accuracy of MPS classifier on the validation set
    with torch.no_grad():
        running_acc = 0.0

        for inputs, labels in loaders["valid"]:
            inputs, labels = inputs.view([batch_size, 128 ** 2]), labels.data

            # Call our MPS to get logit scores and predictions
            scores = mps(inputs)
            _, preds = torch.max(scores, 1)
            running_acc += torch.sum(preds == labels).item() / batch_size

    print(f"Validation accuracy:          {running_acc / num_batches['valid']:.4f}")
    print(f"Runtime so far:         {int(time.time()-start_time)} sec\n")
# Out:
# ### Epoch 1 ###
# Average loss:           2989.7849
# Average train accuracy: 0.3194
# Validation accuracy:          0.4115
# Runtime so far:         30 sec
#
# ### Epoch 2 ###
# Average loss:           2.2395
# Average train accuracy: 0.3194
# Validation accuracy:          0.2682
# Runtime so far:         57 sec
#
# ### Epoch 3 ###
# Average loss:           1.1549
# Average train accuracy: 0.3455
# Validation accuracy:          0.3229
# Runtime so far:         86 sec
#
# ### Epoch 4 ###
# Average loss:           1.0957
# Average train accuracy: 0.3559
# Validation accuracy:          0.3984
# Runtime so far:         115 sec
#
# ### Epoch 5 ###
# Average loss:           1.1072
# Average train accuracy: 0.3455
# Validation accuracy:          0.3880
# Runtime so far:         145 sec
#
# ### Epoch 6 ###
# Average loss:           1.1102
# Average train accuracy: 0.3733
# Validation accuracy:          0.3828
# Runtime so far:         172 sec
#
# ### Epoch 7 ###
# Average loss:           1.0977
# Average train accuracy: 0.3299
# Validation accuracy:          0.3932
# Runtime so far:         204 sec
#
# ### Epoch 8 ###
# Average loss:           1.1026
# Average train accuracy: 0.3038
# Validation accuracy:          0.3698
# Runtime so far:         234 sec
#
# ### Epoch 9 ###
# Average loss:           1.1031
# Average train accuracy: 0.3160
# Validation accuracy:          0.3672
# Runtime so far:         262 sec
#
# ### Epoch 10 ###
# Average loss:           1.0989
# Average train accuracy: 0.3576
# Validation accuracy:          0.3984
# Runtime so far:         290 sec
#
# ### Epoch 11 ###
# Average loss:           1.0990
# Average train accuracy: 0.3455
# Validation accuracy:          0.4036
# Runtime so far:         321 sec
#
# ### Epoch 12 ###
# Average loss:           1.0972
# Average train accuracy: 0.3559
# Validation accuracy:          0.4062
# Runtime so far:         350 sec
#
# ### Epoch 13 ###
# Average loss:           1.0987
# Average train accuracy: 0.3646
# Validation accuracy:          0.3906
# Runtime so far:         379 sec
#
# ### Epoch 14 ###
# Average loss:           1.0997
# Average train accuracy: 0.3628
# Validation accuracy:          0.4323
# Runtime so far:         409 sec
#
# ### Epoch 15 ###
# Average loss:           1.0983
# Average train accuracy: 0.3733
# Validation accuracy:          0.4323
# Runtime so far:         439 sec
#
# ### Epoch 16 ###
# Average loss:           1.0983
# Average train accuracy: 0.3785
# Validation accuracy:          0.3854
# Runtime so far:         466 sec
#
# ### Epoch 17 ###
# Average loss:           1.0960
# Average train accuracy: 0.3750
# Validation accuracy:          0.4115
# Runtime so far:         497 sec
#
# ### Epoch 18 ###
# Average loss:           1.0981
# Average train accuracy: 0.3750
# Validation accuracy:          0.4219
# Runtime so far:         526 sec
#
# ### Epoch 19 ###
# Average loss:           1.0969
# Average train accuracy: 0.3368
# Validation accuracy:          0.4036
# Runtime so far:         555 sec
#
# ### Epoch 20 ###
# Average loss:           1.0987
# Average train accuracy: 0.3698
# Validation accuracy:          0.3958
# Runtime so far:         585 sec
#
# ### Epoch 21 ###
# Average loss:           1.0952
# Average train accuracy: 0.3455
# Validation accuracy:          0.3672
# Runtime so far:         616 sec
#
# ### Epoch 22 ###
# Average loss:           1.0973
# Average train accuracy: 0.3906
# Validation accuracy:          0.4141
# Runtime so far:         645 sec
#
# ### Epoch 23 ###
# Average loss:           1.0921
# Average train accuracy: 0.3802
# Validation accuracy:          0.3724
# Runtime so far:         673 sec
#
# ### Epoch 24 ###
# Average loss:           1.0920
# Average train accuracy: 0.3524
# Validation accuracy:          0.4089
# Runtime so far:         705 sec
#
# ### Epoch 25 ###
# Average loss:           1.0901
# Average train accuracy: 0.3715
# Validation accuracy:          0.4062
# Runtime so far:         736 sec
#
# ### Epoch 26 ###
# Average loss:           1.0767
# Average train accuracy: 0.4080
# Validation accuracy:          0.4167
# Runtime so far:         765 sec
#
# ### Epoch 27 ###
# Average loss:           1.0731
# Average train accuracy: 0.4097
# Validation accuracy:          0.4740
# Runtime so far:         796 sec
#
# ### Epoch 28 ###
# Average loss:           1.0533
# Average train accuracy: 0.4740
# Validation accuracy:          0.5130
# Runtime so far:         827 sec
#
# ### Epoch 29 ###
# Average loss:           0.9909
# Average train accuracy: 0.4826
# Validation accuracy:          0.5104
# Runtime so far:         856 sec
#
# ### Epoch 30 ###
# Average loss:           0.9951
# Average train accuracy: 0.4497
# Validation accuracy:          0.4948
# Runtime so far:         885 sec
#
# ### Epoch 31 ###
# Average loss:           0.9196
# Average train accuracy: 0.5365
# Validation accuracy:          0.5573
# Runtime so far:         916 sec
#
# ### Epoch 32 ###
# Average loss:           0.9227
# Average train accuracy: 0.5243
# Validation accuracy:          0.6042
# Runtime so far:         945 sec
#
# ### Epoch 33 ###
# Average loss:           0.9009
# Average train accuracy: 0.5434
# Validation accuracy:          0.6172
# Runtime so far:         975 sec
#
# ### Epoch 34 ###
# Average loss:           0.9059
# Average train accuracy: 0.5590
# Validation accuracy:          0.6484
# Runtime so far:         1005 sec
#
# ### Epoch 35 ###
# Average loss:           0.9052
# Average train accuracy: 0.5764
# Validation accuracy:          0.5547
# Runtime so far:         1037 sec
#
# ### Epoch 36 ###
# Average loss:           0.8668
# Average train accuracy: 0.6059
# Validation accuracy:          0.6198
# Runtime so far:         1066 sec
#
# ### Epoch 37 ###
# Average loss:           0.8484
# Average train accuracy: 0.6215
# Validation accuracy:          0.6406
# Runtime so far:         1095 sec
#
# ### Epoch 38 ###
# Average loss:           0.8231
# Average train accuracy: 0.6649
# Validation accuracy:          0.6120
# Runtime so far:         1126 sec
#
# ### Epoch 39 ###
# Average loss:           0.9668
# Average train accuracy: 0.6267
# Validation accuracy:          0.5833
# Runtime so far:         1157 sec
#
# ### Epoch 40 ###
# Average loss:           0.9880
# Average train accuracy: 0.5295
# Validation accuracy:          0.6068
# Runtime so far:         1186 sec
#
# ### Epoch 41 ###
# Average loss:           0.9085
# Average train accuracy: 0.5972
# Validation accuracy:          0.6016
# Runtime so far:         1215 sec
#
# ### Epoch 42 ###
# Average loss:           0.8654
# Average train accuracy: 0.6545
# Validation accuracy:          0.6328
# Runtime so far:         1244 sec
#
# ### Epoch 43 ###
# Average loss:           0.8333
# Average train accuracy: 0.6372
# Validation accuracy:          0.6589
# Runtime so far:         1273 sec
#
# ### Epoch 44 ###
# Average loss:           1.0463
# Average train accuracy: 0.5660
# Validation accuracy:          0.3359
# Runtime so far:         1301 sec
#
# ### Epoch 45 ###
# Average loss:           1.0981
# Average train accuracy: 0.3889
# Validation accuracy:          0.3672
# Runtime so far:         1331 sec
#
# ### Epoch 46 ###
# Average loss:           1.0974
# Average train accuracy: 0.3698
# Validation accuracy:          0.3411
# Runtime so far:         1359 sec
#
# ### Epoch 47 ###
# Average loss:           1.0973
# Average train accuracy: 0.3698
# Validation accuracy:          0.3698
# Runtime so far:         1388 sec
#
# ### Epoch 48 ###
# Average loss:           1.0982
# Average train accuracy: 0.3837
# Validation accuracy:          0.3359
# Runtime so far:         1417 sec
#
# ### Epoch 49 ###
# Average loss:           1.0957
# Average train accuracy: 0.3958
# Validation accuracy:          0.3776
# Runtime so far:         1447 sec
#
# ### Epoch 50 ###
# Average loss:           1.0948
# Average train accuracy: 0.4306
# Validation accuracy:          0.3307
# Runtime so far:         1477 sec
#
# ### Epoch 51 ###
# Average loss:           1.1095
# Average train accuracy: 0.4010
# Validation accuracy:          0.3411
# Runtime so far:         1506 sec
#
# ### Epoch 52 ###
# Average loss:           1.0954
# Average train accuracy: 0.4149
# Validation accuracy:          0.3984
# Runtime so far:         1535 sec
#
# ### Epoch 53 ###
# Average loss:           1.1015
# Average train accuracy: 0.4115
# Validation accuracy:          0.3411
# Runtime so far:         1567 sec
#
# ### Epoch 54 ###
# Average loss:           1.0953
# Average train accuracy: 0.4306
# Validation accuracy:          0.3932
# Runtime so far:         1598 sec
#
# ### Epoch 55 ###
# Average loss:           1.0947
# Average train accuracy: 0.4115
# Validation accuracy:          0.4115
# Runtime so far:         1629 sec
# ### Epoch 56 ###
# Average loss:           1.0938
# Average train accuracy: 0.4062
# Validation accuracy:          0.3620
# Runtime so far:         1657 sec
#
# ### Epoch 57 ###
# Average loss:           1.0904
# Average train accuracy: 0.4097
# Validation accuracy:          0.4271
# Runtime so far:         1685 sec
#
# ### Epoch 58 ###
# Average loss:           1.0811
# Average train accuracy: 0.3646
# Validation accuracy:          0.3802
# Runtime so far:         1715 sec
#
# ### Epoch 59 ###
# Average loss:           1.0675
# Average train accuracy: 0.4340
# Validation accuracy:          0.3932
# Runtime so far:         1745 sec
#
# ### Epoch 60 ###
# Average loss:           1.0415
# Average train accuracy: 0.4497
# Validation accuracy:          0.5312
# Runtime so far:         1776 sec
#
# ### Epoch 61 ###
# Average loss:           0.9277
# Average train accuracy: 0.6007
# Validation accuracy:          0.5781
# Runtime so far:         1806 sec
#
# ### Epoch 62 ###
# Average loss:           0.9036
# Average train accuracy: 0.5868
# Validation accuracy:          0.5964
# Runtime so far:         1835 sec
#
# ### Epoch 63 ###
# Average loss:           0.8620
# Average train accuracy: 0.6615
# Validation accuracy:          0.6380
# Runtime so far:         1866 sec
#
# ### Epoch 64 ###
# Average loss:           0.7951
# Average train accuracy: 0.6684
# Validation accuracy:          0.6120
# Runtime so far:         1897 sec
#
# ### Epoch 65 ###
# Average loss:           0.7925
# Average train accuracy: 0.7014
# Validation accuracy:          0.6302
# Runtime so far:         1929 sec
#
# ### Epoch 66 ###
# Average loss:           0.7263
# Average train accuracy: 0.7274
# Validation accuracy:          0.7214
# Runtime so far:         1958 sec
#
# ### Epoch 67 ###
# Average loss:           0.7373
# Average train accuracy: 0.7292
# Validation accuracy:          0.7161
# Runtime so far:         1988 sec
#
# ### Epoch 68 ###
# Average loss:           0.7925
# Average train accuracy: 0.7274
# Validation accuracy:          0.7161
# Runtime so far:         2018 sec
#
# ### Epoch 69 ###
# Average loss:           0.7350
# Average train accuracy: 0.7500
# Validation accuracy:          0.7318
# Runtime so far:         2048 sec
#
# ### Epoch 70 ###
# Average loss:           0.6830
# Average train accuracy: 0.7743
# Validation accuracy:          0.7500
# Runtime so far:         2078 sec
#
# ### Epoch 71 ###
# Average loss:           0.6118
# Average train accuracy: 0.7674
# Validation accuracy:          0.7422
# Runtime so far:         2110 sec
#
# ### Epoch 72 ###
# Average loss:           0.6623
# Average train accuracy: 0.7969
# Validation accuracy:          0.7917
# Runtime so far:         2139 sec
#
# ### Epoch 73 ###
# Average loss:           0.7402
# Average train accuracy: 0.7969
# Validation accuracy:          0.7083
# Runtime so far:         2166 sec
#
# ### Epoch 74 ###
# Average loss:           0.7090
# Average train accuracy: 0.7708
# Validation accuracy:          0.7578
# Runtime so far:         2196 sec
#
# ### Epoch 75 ###
# Average loss:           0.7529
# Average train accuracy: 0.7535
# Validation accuracy:          0.7786
# Runtime so far:         2228 sec
#
# ### Epoch 76 ###
# Average loss:           0.8126
# Average train accuracy: 0.7622
# Validation accuracy:          0.6771
# Runtime so far:         2258 sec
#
# ### Epoch 77 ###
# Average loss:           0.8650
# Average train accuracy: 0.6562
# Validation accuracy:          0.6693
# Runtime so far:         2287 sec
#
# ### Epoch 78 ###
# Average loss:           0.7142
# Average train accuracy: 0.7483
# Validation accuracy:          0.7526
# Runtime so far:         2315 sec
#
# ### Epoch 79 ###
# Average loss:           0.6848
# Average train accuracy: 0.7517
# Validation accuracy:          0.7344
# Runtime so far:         2344 sec
#
# ### Epoch 80 ###
# Average loss:           0.5857
# Average train accuracy: 0.7726
# Validation accuracy:          0.7526
# Runtime so far:         2375 sec
#
# ### Epoch 81 ###
# Average loss:           0.6485
# Average train accuracy: 0.7726
# Validation accuracy:          0.8073
# Runtime so far:         2408 sec
#
# ### Epoch 82 ###
# Average loss:           0.6122
# Average train accuracy: 0.7708
# Validation accuracy:          0.7109
# Runtime so far:         2437 sec
#
# ### Epoch 83 ###
# Average loss:           0.6756
# Average train accuracy: 0.7500
# Validation accuracy:          0.7917
# Runtime so far:         2468 sec
#
# ### Epoch 84 ###
# Average loss:           0.6159
# Average train accuracy: 0.7847
# Validation accuracy:          0.7917
# Runtime so far:         2497 sec
#
# ### Epoch 85 ###
# Average loss:           0.5229
# Average train accuracy: 0.7934
# Validation accuracy:          0.7812
# Runtime so far:         2530 sec
#
# ### Epoch 86 ###
# Average loss:           0.6358
# Average train accuracy: 0.7569
# Validation accuracy:          0.7370
# Runtime so far:         2561 sec
#
# ### Epoch 87 ###
# Average loss:           0.5927
# Average train accuracy: 0.7448
# Validation accuracy:          0.7995
# Runtime so far:         2590 sec
#
# ### Epoch 88 ###
# Average loss:           0.5932
# Average train accuracy: 0.7986
# Validation accuracy:          0.8047
# Runtime so far:         2620 sec
#
# ### Epoch 89 ###
# Average loss:           0.6246
# Average train accuracy: 0.7830
# Validation accuracy:          0.7708
# Runtime so far:         2649 sec
#
# ### Epoch 90 ###
# Average loss:           0.5678
# Average train accuracy: 0.7951
# Validation accuracy:          0.7865
# Runtime so far:         2680 sec
#
# ### Epoch 91 ###
# Average loss:           0.6310
# Average train accuracy: 0.7604
# Validation accuracy:          0.7708
# Runtime so far:         2712 sec
#
# ### Epoch 92 ###
# Average loss:           0.6690
# Average train accuracy: 0.7969
# Validation accuracy:          0.7161
# Runtime so far:         2747 sec
#
# ### Epoch 93 ###
# Average loss:           0.6200
# Average train accuracy: 0.7691
# Validation accuracy:          0.7943
# Runtime so far:         2793 sec
#
# ### Epoch 94 ###
# Average loss:           0.6062
# Average train accuracy: 0.7830
# Validation accuracy:          0.8203
# Runtime so far:         2839 sec
#
# ### Epoch 95 ###
# Average loss:           0.6132
# Average train accuracy: 0.7882
# Validation accuracy:          0.7995
# Runtime so far:         2882 sec
#
# ### Epoch 96 ###
# Average loss:           0.5707
# Average train accuracy: 0.8038
# Validation accuracy:          0.7682
# Runtime so far:         2911 sec
#
# ### Epoch 97 ###
# Average loss:           0.5066
# Average train accuracy: 0.8247
# Validation accuracy:          0.8073
# Runtime so far:         2940 sec
#
# ### Epoch 98 ###
# Average loss:           0.4707
# Average train accuracy: 0.8160
# Validation accuracy:          0.7630
# Runtime so far:         2969 sec
#
# ### Epoch 99 ###
# Average loss:           0.4998
# Average train accuracy: 0.8108
# Validation accuracy:          0.8203
# Runtime so far:         3001 sec
#
# ### Epoch 100 ###
# Average loss:           0.5769
# Average train accuracy: 0.7934
# Validation accuracy:          0.8151
# Runtime so far:         3030 sec
